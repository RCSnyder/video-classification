# %%
# This notebook will split the data stored in a directory into a train, validation and test set

# %%
import os
from pathlib import Path
import pathlib
import cv2
import pandas as pd
import numpy as np
import shutil

# %%
TARGET_DIR = Path("D:/__School/__Masters/____2021fALL/5280_aiwearables/final_gesture_frame_splits")

MAIN_DATA_DIR = Path("D:/__School/__Masters/____2021fALL/5280_aiwearables/combined_1st_2nd_3rd_iter_frames")

DIRS = [Path("train"), Path("validation"), Path("test")]
GESTURES = ["CLOCKWISE", "COUNTERCLOCKWISE", "DOWN", "UP", "LEFT", "RIGHT"]

LABEL_DICT = {"CLOCKWISE": 0, "COUNTERCLOCKWISE": 1, "DOWN": 2, "UP": 3, "LEFT": 4, "RIGHT": 5}

# %%
def make_train_val_test_folders(target_dir, dirs):
    """given a directory, generate 3 new directories named train, validation, test"""
    new_dir_path = None
    for dir_name in dirs:
        new_dir_path = target_dir.joinpath(Path(dir_name))
        pathlib.Path(new_dir_path).mkdir(parents=True, exist_ok=True)

# %%
# make_train_val_test_folders(TARGET_DIR, DIRS)

# %%
def make_gesture_subfolders(target_directory, gestures, dirs):
    """creates gesture subfolders in a given directory that contain train, validation, test dirs"""
    dir_path = None
    for dir_name in dirs:
        split_dir_path = target_directory.joinpath(Path(dir_name))
        
        for gesture_name in gestures:
            gesture_dir_path = split_dir_path.joinpath(Path(gesture_name))
            pathlib.Path(gesture_dir_path).mkdir(parents=True, exist_ok=True)

# %%
# make_gesture_subfolders(TARGET_DIR, GESTURES, DIRS)

# %%
def get_video_directories(main_directory):
    """returns a list of all of the subfolders that are videos within a main directory"""
    video_fnames = []
    for path, subdirs, files in os.walk(main_directory):
        for name in subdirs:
            video_fnames.append(str(Path(os.path.join(path, name))))
    return video_fnames[6:]

# %%
all_videos_dir_names = get_video_directories(MAIN_DATA_DIR)
all_videos_dir_names
# Out:
# ['D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00001',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00002',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00003',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00004',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00005',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00006',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00007',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00008',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00009',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\AW_CLOCKWISE_00010',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\cooper_s_CLOCKWISE_00011',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\cooper_s_CLOCKWISE_00012',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\cooper_s_CLOCKWISE_00013',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\cooper_s_CLOCKWISE_00014',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\cooper_s_CLOCKWISE_00015',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Daniel_M_CLOCKWISE_00016',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Daniel_M_CLOCKWISE_00017',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Daniel_M_CLOCKWISE_00018',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Daniel_M_CLOCKWISE_00019',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Daniel_M_CLOCKWISE_00020',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\emmanuel_z_CLOCKWISE_00021',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\emmanuel_z_CLOCKWISE_00022',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\emmanuel_z_CLOCKWISE_00023',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\emmanuel_z_CLOCKWISE_00024',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\emmanuel_z_CLOCKWISE_00025',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Ian_z_CLOCKWISE_00026',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Ian_z_CLOCKWISE_00027',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Ian_z_CLOCKWISE_00028',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Ian_z_CLOCKWISE_00029',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Ian_z_CLOCKWISE_00030',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00031',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00032',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00033',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00034',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00035',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00036',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IA_CLOCKWISE_00037',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IM_CLOCKWISE_00038',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\IM_CLOCKWISE_00039',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00040',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00041',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00042',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00043',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00044',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00045',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00046',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00047',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00048',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\JBG_CLOCKWISE_00049',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KH_CLOCKWISE_00050',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00051',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00052',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00053',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00054',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00055',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00056',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00057',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00058',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00059',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\KP_CLOCKWISE_00060',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Lori_L_CLOCKWISE_00061',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Lori_L_CLOCKWISE_00062',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Lori_L_CLOCKWISE_00063',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Lori_L_CLOCKWISE_00064',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Lori_L_CLOCKWISE_00065',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Madeline_U_CLOCKWISE_00066',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Madeline_U_CLOCKWISE_00067',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Madeline_U_CLOCKWISE_00068',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Madeline_U_CLOCKWISE_00069',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Madeline_U_CLOCKWISE_00070',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00071',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00072',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00073',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00074',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00075',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00076',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00077',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00078',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00079',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00080',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\MCM_CLOCKWISE_00081',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Miguel_Q_CLOCKWISE_00082',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Miguel_Q_CLOCKWISE_00083',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Miguel_Q_CLOCKWISE_00084',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Miguel_Q_CLOCKWISE_00085',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Miguel_Q_CLOCKWISE_00086',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RAM_CLOCKWISE_00087',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RAM_CLOCKWISE_00088',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RAM_CLOCKWISE_00089',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RAM_CLOCKWISE_00090',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RAM_CLOCKWISE_00091',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RCS_CLOCKWISE_00092',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\RCS_CLOCKWISE_00093',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SNB_CLOCKWISE_00094',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SNB_CLOCKWISE_00095',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SNB_CLOCKWISE_00096',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SNB_CLOCKWISE_00097',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SNB_CLOCKWISE_00098',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00099',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00100',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00101',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00102',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00103',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00104',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00105',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00106',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00107',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\SP_CLOCKWISE_00108',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Will_B_CLOCKWISE_00109',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Will_B_CLOCKWISE_00110',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Will_B_CLOCKWISE_00111',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Will_B_CLOCKWISE_00112',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Will_B_CLOCKWISE_00113',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Yen_P_CLOCKWISE_00114',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Yen_P_CLOCKWISE_00115',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Yen_P_CLOCKWISE_00116',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Yen_P_CLOCKWISE_00117',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\CLOCKWISE\\Yen_P_CLOCKWISE_00118',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00001',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00002',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00003',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00004',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00005',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00006',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00007',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00008',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00009',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\AW_COUNTERCLOCKWISE_00010',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\cooper_s_COUNTERCLOCKWISE_00011',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\cooper_s_COUNTERCLOCKWISE_00012',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\cooper_s_COUNTERCLOCKWISE_00013',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\cooper_s_COUNTERCLOCKWISE_00014',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\cooper_s_COUNTERCLOCKWISE_00015',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Daniel_M_COUNTERCLOCKWISE_00016',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Daniel_M_COUNTERCLOCKWISE_00017',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Daniel_M_COUNTERCLOCKWISE_00018',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Daniel_M_COUNTERCLOCKWISE_00019',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Daniel_M_COUNTERCLOCKWISE_00020',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\emmanuel_z_COUNTERCLOCKWISE_00021',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\emmanuel_z_COUNTERCLOCKWISE_00022',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\emmanuel_z_COUNTERCLOCKWISE_00023',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\emmanuel_z_COUNTERCLOCKWISE_00024',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\emmanuel_z_COUNTERCLOCKWISE_00025',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Ian_z_COUNTERCLOCKWISE_00026',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Ian_z_COUNTERCLOCKWISE_00027',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Ian_z_COUNTERCLOCKWISE_00028',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Ian_z_COUNTERCLOCKWISE_00029',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Ian_z_COUNTERCLOCKWISE_00030',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00031',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00032',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00033',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00034',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00035',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00036',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IA_COUNTERCLOCKWISE_00037',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IM_COUNTERCLOCKWISE_00038',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\IM_COUNTERCLOCKWISE_00039',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00040',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00041',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00042',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00043',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00044',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00045',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00046',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00047',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00048',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\JBG_COUNTERCLOCKWISE_00049',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KH_COUNTERCLOCKWISE_00050',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00051',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00052',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00053',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00054',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00055',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00056',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00057',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00058',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00059',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\KP_COUNTERCLOCKWISE_00060',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Lori_L_COUNTERCLOCKWISE_00061',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Lori_L_COUNTERCLOCKWISE_00062',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Lori_L_COUNTERCLOCKWISE_00063',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Lori_L_COUNTERCLOCKWISE_00064',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Lori_L_COUNTERCLOCKWISE_00065',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Madeline_U_COUNTERCLOCKWISE_00066',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Madeline_U_COUNTERCLOCKWISE_00067',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Madeline_U_COUNTERCLOCKWISE_00068',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Madeline_U_COUNTERCLOCKWISE_00069',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Madeline_U_COUNTERCLOCKWISE_00070',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00071',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00072',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00073',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00074',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00075',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00076',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00077',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00078',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00079',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00080',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00081',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00082',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00083',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00084',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\MCM_COUNTERCLOCKWISE_00085',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Miguel_Q_COUNTERCLOCKWISE_00086',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Miguel_Q_COUNTERCLOCKWISE_00087',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Miguel_Q_COUNTERCLOCKWISE_00088',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Miguel_Q_COUNTERCLOCKWISE_00089',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Miguel_Q_COUNTERCLOCKWISE_00090',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RAM_COUNTERCLOCKWISE_00091',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RAM_COUNTERCLOCKWISE_00092',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RAM_COUNTERCLOCKWISE_00093',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RAM_COUNTERCLOCKWISE_00094',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RAM_COUNTERCLOCKWISE_00095',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RCS_COUNTERCLOCKWISE_00096',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\RCS_COUNTERCLOCKWISE_00097',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SNB_COUNTERCLOCKWISE_00098',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SNB_COUNTERCLOCKWISE_00099',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SNB_COUNTERCLOCKWISE_00100',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SNB_COUNTERCLOCKWISE_00101',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SNB_COUNTERCLOCKWISE_00102',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SNB_COUNTERCLOCKWISE_00103',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00104',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00105',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00106',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00107',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00108',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00109',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00110',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00111',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00112',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\SP_COUNTERCLOCKWISE_00113',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Will_B_COUNTERCLOCKWISE_00114',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Will_B_COUNTERCLOCKWISE_00115',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Will_B_COUNTERCLOCKWISE_00116',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Will_B_COUNTERCLOCKWISE_00117',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Will_B_COUNTERCLOCKWISE_00118',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Yen_P_COUNTERCLOCKWISE_00119',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Yen_P_COUNTERCLOCKWISE_00120',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Yen_P_COUNTERCLOCKWISE_00121',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Yen_P_COUNTERCLOCKWISE_00122',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\COUNTERCLOCKWISE\\Yen_P_COUNTERCLOCKWISE_00123',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00001',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00002',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00003',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00004',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00005',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00006',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00007',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00008',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00009',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\AW_DOWN_00010',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00011',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00012',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00013',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00014',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00015',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00016',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00017',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00018',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00019',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\cooper_s_DOWN_00020',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00021',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00022',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00023',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00024',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00025',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00026',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00027',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00028',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00029',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Daniel_M_DOWN_00030',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00031',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00032',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00033',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00034',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00035',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00036',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00037',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00038',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00039',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\emmanuel_z_DOWN_00040',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00041',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00042',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00043',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00044',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00045',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00046',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00047',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00048',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00049',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Ian_z_DOWN_00050',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00051',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00052',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00053',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00054',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00055',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00056',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IA_DOWN_00057',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IM_DOWN_00058',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\IM_DOWN_00059',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00060',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00061',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00062',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00063',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00064',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00065',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00066',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00067',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00068',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\JBG_DOWN_00069',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KH_DOWN_00070',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00071',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00072',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00073',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00074',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00075',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00076',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00077',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00078',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00079',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\KP_DOWN_00080',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00081',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00082',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00083',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00084',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00085',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00086',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00087',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00088',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00089',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Lori_L_DOWN_00090',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00091',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00092',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00093',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00094',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00095',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00096',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00097',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00098',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00099',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Madeline_U_DOWN_00100',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00101',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00102',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00103',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00104',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00105',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00106',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00107',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00108',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00109',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00110',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\MCM_DOWN_00111',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00112',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00113',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00114',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00115',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00116',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00117',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00118',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00119',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00120',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\Miguel_Q_DOWN_00121',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RAM_DOWN_00122',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RAM_DOWN_00123',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RAM_DOWN_00124',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RAM_DOWN_00125',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RAM_DOWN_00126',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RCS_DOWN_00127',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\RCS_DOWN_00128',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\SNB_DOWN_00129',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\SNB_DOWN_00130',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\DOWN\\SNB_DOWN_00131',
# ...
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Daniel_M_UP_00030',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00031',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00032',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00033',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00034',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00035',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00036',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00037',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00038',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00039',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\emmanuel_z_UP_00040',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00041',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00042',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00043',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00044',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00045',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00046',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00047',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00048',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00049',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Ian_z_UP_00050',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00051',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00052',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00053',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00054',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00055',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00056',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IA_UP_00057',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IM_UP_00058',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\IM_UP_00059',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00060',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00061',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00062',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00063',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00064',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00065',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00066',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00067',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00068',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\JBG_UP_00069',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KH_UP_00070',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00071',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00072',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00073',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00074',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00075',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00076',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00077',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00078',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00079',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\KP_UP_00080',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00081',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00082',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00083',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00084',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00085',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00086',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00087',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00088',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00089',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Lori_L_UP_00090',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00091',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00092',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00093',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00094',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00095',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00096',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00097',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00098',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00099',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Madeline_U_UP_00100',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00101',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00102',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00103',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00104',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00105',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00106',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00107',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00108',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00109',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00110',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00111',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\MCM_UP_00112',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00113',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00114',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00115',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00116',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00117',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00118',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00119',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00120',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00121',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Miguel_Q_UP_00122',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RAM_UP_00123',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RAM_UP_00124',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RAM_UP_00125',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RAM_UP_00126',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RAM_UP_00127',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RCS_UP_00128',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\RCS_UP_00129',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00130',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00131',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00132',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00133',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00134',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00135',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00136',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00137',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00138',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SNB_UP_00139',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00140',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00141',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00142',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00143',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00144',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00145',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00146',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00147',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00148',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\SP_UP_00149',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00150',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00151',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00152',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00153',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00154',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00155',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00156',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00157',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00158',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Will_B_UP_00159',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00160',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00161',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00162',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00163',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00164',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00165',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00166',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00167',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00168',
#  'D:\\__School\\__Masters\\____2021fALL\\5280_aiwearables\\combined_1st_2nd_3rd_iter_frames\\UP\\Yen_P_UP_00169']

# %%
def get_video_metadata_df(list_of_video_directories):
    """extracts the participant, class, num_frames in a list of full directories
       returns a dataframe"""
    df_list = []
    
    for vid_name in list_of_video_directories:
        
        # split video into list 
        # ['D:','__School','__Masters','____2021fALL',
        #  '5280_aiwearables','combined_1st_2nd_iter_frames',
        #  'CLOCKWISE','AW_CLOCKWISE_00002']
        split_vid_name = vid_name.split("\\")
        
        # get full path
        video_path = Path(vid_name)
        
        # get class name
        gesture_class = split_vid_name[-2]
        
        # get participant_id
        video_dir_name_split = split_vid_name[-1].split("_")
        if len(video_dir_name_split) == 4:
            participant_id = "_".join(video_dir_name_split[:2])
        else:
            participant_id = video_dir_name_split[0]
            
        # get frame count
        frames = os.listdir(vid_name)
        num_frames = len(frames)
        
        df_list.append({
            "full_path": video_path,
            "gesture": gesture_class,
            "participant_id": participant_id,
            "num_frames": num_frames
        })
        
    df = pd.DataFrame(df_list)
    return df

# %%
df = get_video_metadata_df(all_videos_dir_names)
df
# Out:
#                                              full_path    gesture  \
# 0    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 1    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 2    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 3    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 4    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# ..                                                 ...        ...
# 910  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 911  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 912  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 913  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 914  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
#
#     participant_id  num_frames
# 0               AW          46
# 1               AW          44
# 2               AW          38
# 3               AW          38
# 4               AW          39
# ..             ...         ...
# 910          Yen_P          47
# 911          Yen_P          57
# 912          Yen_P          52
# 913          Yen_P          47
# 914          Yen_P          48
#
# [915 rows x 4 columns]

# %%
df.participant_id.value_counts()
# Out:
# MCM           72
# AW            60
# SP            60
# JBG           60
# KP            60
# SNB           51
# cooper_s      50
# Will_B        50
# Miguel_Q      50
# Madeline_U    50
# Lori_L        50
# Ian_z         50
# emmanuel_z    50
# Daniel_M      50
# Yen_P         50
# IA            42
# RAM           30
# IM            12
# RCS           12
# KH             6
# Name: participant_id, dtype: int64

# %%
df.gesture.value_counts()
# Out:
# RIGHT               169
# UP                  169
# DOWN                168
# LEFT                168
# COUNTERCLOCKWISE    123
# CLOCKWISE           118
# Name: gesture, dtype: int64

# %%
from sklearn.model_selection import train_test_split
full_train, test = train_test_split(df, stratify=df.gesture, test_size=0.15)
train, validation = train_test_split(full_train, stratify=full_train.gesture, test_size=0.15)

# %%
train.participant_id.value_counts()
# Out:
# MCM           59
# KP            47
# SP            44
# JBG           42
# cooper_s      39
# Will_B        39
# Ian_z         38
# Miguel_Q      38
# Madeline_U    37
# emmanuel_z    36
# Yen_P         36
# Lori_L        35
# Daniel_M      35
# AW            35
# SNB           34
# IA            29
# RAM           18
# RCS            7
# IM             7
# KH             5
# Name: participant_id, dtype: int64

# %%
train.gesture.value_counts()
# Out:
# LEFT                122
# RIGHT               122
# UP                  122
# DOWN                121
# COUNTERCLOCKWISE     88
# CLOCKWISE            85
# Name: gesture, dtype: int64

# %%
test.gesture.value_counts()
# Out:
# UP                  26
# RIGHT               25
# DOWN                25
# LEFT                25
# COUNTERCLOCKWISE    19
# CLOCKWISE           18
# Name: gesture, dtype: int64

# %%
from sklearn.model_selection import train_test_split

def append_train_validation_test_split(df, train, validation, test, stratify_subject=False, stratify_gesture=False, random_state = 1):
    """appends a 'train', 'validation', 'test' onto the dataframe 
       based on the train, validation, test proportions and type, 'subjectwise', stratified"""
    dff = df.copy()
    
    if stratify_subject:
        full_train, test = train_test_split(df, stratify=df.participant_id, test_size=test)
        train, validation = train_test_split(full_train, stratify=full_train.participant_id, test_size=0.15)
        
    elif stratify_gesture:
        full_train, test = train_test_split(df, stratify=df.gesture, test_size=test)
        train, validation = train_test_split(full_train, stratify=full_train.gesture, test_size=validation)
        
    else:
        full_train, test = train_test_split(df, stratify=df.gesture, test_size=test)
        train, validation = train_test_split(full_train, stratify=full_train.gesture, test_size=validation)
    
    df["train"] = df.full_path.isin(train.full_path)
    df["validation"] = df.full_path.isin(validation.full_path)
    df["test"] = df.full_path.isin(test.full_path)
    
    return dff, train, validation, test

# %%
dff, df_train, df_val, df_test = append_train_validation_test_split(df, .7, .15, .15, stratify_subject=False, stratify_gesture=True, random_state = 1)

# %%
dff
# Out:
#                                              full_path    gesture  \
# 0    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 1    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 2    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 3    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 4    D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# ..                                                 ...        ...
# 910  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 911  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 912  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 913  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 914  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
#
#     participant_id  num_frames  train  validation   test
# 0               AW          46  False       False   True
# 1               AW          44   True       False  False
# 2               AW          38   True       False  False
# 3               AW          38   True       False  False
# 4               AW          39   True       False  False
# ..             ...         ...    ...         ...    ...
# 910          Yen_P          47   True       False  False
# 911          Yen_P          57   True       False  False
# 912          Yen_P          52   True       False  False
# 913          Yen_P          47   True       False  False
# 914          Yen_P          48   True       False  False
#
# [915 rows x 7 columns]

# %%
def get_stats(df):
    print(df.participant_id.value_counts())
    print(df.gesture.value_counts())
    print()

# %%
for x in [df, df_train, df_val, df_test]:
    get_stats(x)
# Out:
# MCM           72
# AW            60
# SP            60
# JBG           60
# KP            60
# SNB           51
# cooper_s      50
# Will_B        50
# Miguel_Q      50
# Madeline_U    50
# Lori_L        50
# Ian_z         50
# emmanuel_z    50
# Daniel_M      50
# Yen_P         50
# IA            42
# RAM           30
# IM            12
# RCS           12
# KH             6
# Name: participant_id, dtype: int64
# RIGHT               169
# UP                  169
# DOWN                168
# LEFT                168
# COUNTERCLOCKWISE    123
# CLOCKWISE           118
# Name: gesture, dtype: int64
#
# MCM           52
# KP            47
# JBG           44
# Yen_P         41
# SP            41
# emmanuel_z    39
# Ian_z         38
# Miguel_Q      37
# Will_B        37
# AW            37
# SNB           37
# Madeline_U    35
# cooper_s      35
# Daniel_M      33
# Lori_L        33
# IA            27
# RAM           26
# IM            11
# RCS            5
# KH             5
# Name: participant_id, dtype: int64
# LEFT                122
# UP                  122
# RIGHT               122
# DOWN                121
# COUNTERCLOCKWISE     88
# CLOCKWISE            85
# Name: gesture, dtype: int64
#
# AW            11
# MCM           10
# Will_B         9
# Daniel_M       9
# SP             8
# Lori_L         8
# JBG            8
# cooper_s       7
# Ian_z          7
# Madeline_U     7
# SNB            7
# IA             6
# Miguel_Q       5
# Yen_P          4
# emmanuel_z     4
# KP             3
# RCS            2
# IM             1
# RAM            1
# Name: participant_id, dtype: int64
# DOWN                22
# UP                  22
# RIGHT               21
# LEFT                21
# COUNTERCLOCKWISE    16
# CLOCKWISE           15
# Name: gesture, dtype: int64
#
# AW            12
# SP            11
# KP            10
# MCM           10
# Lori_L         9
# IA             9
# cooper_s       8
# Miguel_Q       8
# Madeline_U     8
# JBG            8
# Daniel_M       8
# SNB            7
# emmanuel_z     7
# Yen_P          5
# Ian_z          5
# RCS            5
# Will_B         4
# RAM            3
# KH             1
# Name: participant_id, dtype: int64
# RIGHT               26
# DOWN                25
# LEFT                25
# UP                  25
# COUNTERCLOCKWISE    19
# CLOCKWISE           18
# Name: gesture, dtype: int64

# %%
df_train
# Out:
#                                              full_path    gesture  \
# 11   D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 573  D:\__School\__Masters\____2021fALL\5280_aiwear...       LEFT
# 795  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 59   D:\__School\__Masters\____2021fALL\5280_aiwear...  CLOCKWISE
# 276  D:\__School\__Masters\____2021fALL\5280_aiwear...       DOWN
# ..                                                 ...        ...
# 760  D:\__School\__Masters\____2021fALL\5280_aiwear...         UP
# 537  D:\__School\__Masters\____2021fALL\5280_aiwear...       LEFT
# 364  D:\__School\__Masters\____2021fALL\5280_aiwear...       DOWN
# 422  D:\__School\__Masters\____2021fALL\5280_aiwear...       LEFT
# 610  D:\__School\__Masters\____2021fALL\5280_aiwear...      RIGHT
#
#     participant_id  num_frames
# 11        cooper_s          33
# 573          Yen_P          69
# 795          Ian_z          94
# 59              KP          51
# 276     emmanuel_z          75
# ..             ...         ...
# 760       cooper_s          27
# 537            SNB          81
# 364            RAM          89
# 422       cooper_s          34
# 610     emmanuel_z          79
#
# [660 rows x 4 columns]

# %%
len(df)
# Out:
# 915

# %%
len(df_train)
# Out:
# 660

# %%
len(df_val)
# Out:
# 117

# %%
len(df_test)
# Out:
# 138

# %%
dff.full_path[0]
# Out:
# WindowsPath('D:/__School/__Masters/____2021fALL/5280_aiwearables/combined_1st_2nd_3rd_iter_frames/CLOCKWISE/AW_CLOCKWISE_00001')

# %%
def copy_train_validation_test(df, main_dir, target_dir):
    """copies the video directories into the corresponding train, validation, test folders"""
    
    # for each row of df
        # split full_path
        # 'D:/__School/__Masters/____2021fALL/5280_aiwearables/combined_1st_2nd_3rd_iter_frames/CLOCKWISE/AW_CLOCKWISE_00001'
        # make it TARGET_DIR = Path("D:/__School/__Masters/____2021fALL/5280_aiwearables/final_gesture_frame_splits")
        
        # if train:
            # insert final_gesture_frame_splits/train before -2
        # if validation
            # insert final_gesture_frame_splits/validation before -2
        # if test
            # insert final_gesture_frame_splits/test before -2
        
        # copy video to new directory
    def per_row(row):
        split_path = str(row.full_path).split("\\")
        
        
        if row.train:
            split_path[-3] = "final_gesture_frame_splits\\train"
            
        elif row.validation:
            split_path[-3] = "final_gesture_frame_splits\\validation"
            
        elif row.test:
            split_path[-3] = "final_gesture_frame_splits\\test"
            
        new_dir = "\\".join(split_path)
        
        #print(row.full_path)
        #print(Path(new_dir))
        
        #copy(row.full_path, Path(new_dir))
        shutil.copytree(row.full_path, Path(new_dir), symlinks=False, ignore=None, copy_function=copy, ignore_dangling_symlinks=False, dirs_exist_ok=False)
    
    df.apply(per_row, axis=1)

# %%
copy_train_validation_test(dff, MAIN_DATA_DIR, TARGET_DIR)

# %%
def generate_annotation_file(input_dir, label_dict, output_dir):
    """generates the annotation.txt for the directory"""
    
    
    def get_video_dir_names(input_dir):
        """returns the list of frame_dirs and class_dirs"""

        # get all file directories
        video_fnames = []
        for path, subdirs, files in os.walk(input_dir):
            for subdir in subdirs:
                video_fnames.append(str(Path(os.path.join(path, subdir))))

        # remove the parent class folder directories 0 to 6
        return video_fnames[6:]

    
    def get_frame_dir_names(input_dir):
        """given a frames directory returns a list of each frame directory"""
        frames_fnames = []
        for path, subdirs, files in os.walk(input_dir):
            for file in files:
                frames_fnames.append(str(Path(os.path.join(path, file))))

        return frames_fnames
    
    
    def get_start_and_end_frame_numbers(input_dir):
        """returns the start and end frame number of a given video directory"""
        start = 1
        end = 0
        frame_fnames = []
        for path, subdirs, files in os.walk(input_dir):
            for name in files:
                frame_fnames.append(str(Path(os.path.join(path, name))))

        end = len(frame_fnames)
        return start, end
    
    
    def get_class_label_id(frame_dir, label_dict):
        """given a frame directory returns the label id"""

        #may only work on windows
        split_dir = str(frame_dir).split("\\")

        for item in split_dir:
            if item in label_dict.keys():
                class_name = item

        return label_dict[class_name]
    
    
    def get_class_name_video_id(video_dir):
        """given a video_dir returns the class name and the video_idx"""
        split_dir = str(video_dir).split("\\")
        class_name = split_dir[-2]
        video_idx = split_dir[-1]

        return "\\".join([class_name, video_idx])
    
    
    # get all file directories
    video_dirs = get_video_dir_names(input_dir)
    
    #open annotation.txt
    annotations = open(os.path.join(output_dir), "a")
    
    for video_dir in video_dirs:
        # extract start_frame and end_frame number (inclusive)
        start_frame, end_frame = get_start_and_end_frame_numbers(video_dir)
        
        # get label id
        label_id = get_class_label_id(video_dir, label_dict)
        
        #get class_name/video_idx
        class_video_idx = get_class_name_video_id(video_dir)
        
        #build annotation string
        annotation_line_item = class_video_idx + " " + str(start_frame) + " " + str(end_frame) + " " + str(label_id) + "\n"
        
        # write to annotation.txt
        annotations.write(annotation_line_item)
    annotations.close()

# %%
# for all train, test, validation directories

for x_dir in [Path("D:/__School/__Masters/____2021fALL/5280_aiwearables/final_gesture_frame_splits/train"),
              Path("D:/__School/__Masters/____2021fALL/5280_aiwearables/final_gesture_frame_splits/validation"),
              Path("D:/__School/__Masters/____2021fALL/5280_aiwearables/final_gesture_frame_splits/test")]:
    
    generate_annotation_file(INPUT_FRAMES_DIRECTORY, LABEL_DICT, OUTPUT_DIRECTORY)

# %%
# make train, validiation, test directories

# copy internal class folders

# make list of all video folders and associated meta data

# generate train, validation, test tags on each one.

# def a function that can apply to every row of the pandas frame 
#that will put the associated video into the new directory path
